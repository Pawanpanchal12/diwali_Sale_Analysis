# %%
# import python libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# import csv file
df = pd.read_csv ('/content/Ecommerce Purchases')

# %%
df
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %%
#Display Top 10 Rows of The Dataset
df.head(10)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %%
#Check Last 10 Rows of The Dataset
df.tail(10)
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %%
#Check Datatype of Each Column
df.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
#Check null values in the dataset
df.isnull()
# Out:
#       Address    Lot  AM or PM  Browser Info  Company  Credit Card  \
# 0       False  False     False         False    False        False
# 1       False  False     False         False    False        False
# 2       False  False     False         False    False        False
# 3       False  False     False         False    False        False
# 4       False  False     False         False    False        False
# ...       ...    ...       ...           ...      ...          ...
# 9995    False  False     False         False    False        False
# 9996    False  False     False         False    False        False
# 9997    False  False     False         False    False        False
# 9998    False  False     False         False    False        False
# 9999    False  False     False         False    False        False
#
#       CC Exp Date  CC Security Code  CC Provider  Email    Job  IP Address  \
# 0           False             False        False  False  False       False
# ...

# %%
#How many rows and columns are there in our Dataset?
len(df.columns)
len(df)
# Out:
# 10000

# %%
#Highest and Lowest Purchase Prices.
df["Purchase Price"]
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
df["Purchase Price"].max()
# Out:
# 99.99

# %%
df["Purchase Price"].min()
# Out:
# 0.0

# %%
#Average Purchase Price
df["Purchase Price"].mean()
# Out:
# 50.347302

# %%
#How many people have French 'fr' as their Language?
df.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
df[df["Language"]=="fr"]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 53                PSC 9431, Box 7059\nAPO AA 29285-1363  14 qD       AM
# 76    49206 Campbell Port\nNorth Cliffordshire, HI 3...  71 iu       PM
# 82    493 Smith Valleys Suite 004\nNew Madelineville...  35 ls       PM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9947      32827 Carl Inlet\nSouth Nicole, NY 38081-6636  40 Dp       PM
# 9951                518 Brown Dam\nGarciaside, IN 33057  71 wq       AM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9980           6061 Dave Lights\nPhillipsview, UT 40500  25 Mv       AM
#
#                                            Browser Info  \
# ...

# %%
#Job Title Contains Engineer
df[df["Job"].str.contains("Engineer",case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 50      41159 Michael Centers\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\nSandraview, SD ...  59 LJ       AM
# 60    7126 Katherine Squares\nPerkinsview, CO 97299-...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9952            9991 Vaughn Hills\nRacheltown, PA 55409  36 KC       PM
# 9970              0060 Keith Stream\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\nEast Shannon, CT 20578...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %%
len(df[df["Job"].str.contains("Engineer",case=False)])
# Out:
# 984

# %%
#Find The Email of the person with the following IP Address: 132.207.160.22
df[df["IP Address"]==("132.207.160.22")]
# Out:
#                             Address    Lot AM or PM  \
# 2  Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
#
#                                         Browser Info  \
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
#
#                       Company   Credit Card CC Exp Date  CC Security Code  \
# 2  Simpson, Williams and Pham  675957666125       08/19               699
#
#     CC Provider                           Email                       Job  \
# 2  JCB 16 digit  amymiller@morales-harrison.com  Customer service manager
#
#        IP Address Language  Purchase Price
# 2  132.207.160.22       de            0.95

# %%
df[df["IP Address"]==("132.207.160.22")]["Email"]
# Out:
# 2    amymiller@morales-harrison.com
# Name: Email, dtype: object

# %%
#How many People have Mastercard as their Credit Card Provider and made a purchase above 50?
df["CC Provider"]
# Out:
# 0                      JCB 16 digit
# 1                        Mastercard
# 2                      JCB 16 digit
# 3                          Discover
# 4       Diners Club / Carte Blanche
#                    ...
# 9995                   JCB 15 digit
# 9996                   JCB 16 digit
# 9997                  VISA 16 digit
# 9998               American Express
# 9999                   JCB 15 digit
# Name: CC Provider, Length: 10000, dtype: object

# %%
df[(df["CC Provider"]=="Mastercard") & (df["Purchase Price"]>50)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 18    461 Christopher Square\nWest Michaelchester, C...  17 SB       PM
# 31                     USNS Alvarado\nFPO AA 27052-1231  26 Lh       PM
# 35    93392 Webb Gardens Apt. 220\nLaurabury, AR 999...  37 om       AM
# 90          431 Bowen Lights\nFergusonborough, MH 01362  31 tG       AM
# ...                                                 ...    ...      ...
# 9941           43757 Brown Lodge\nValerieberg, PR 88518  68 DG       AM
# 9948  95544 Johnson Isle Suite 939\nMichaelberg, RI ...  91 bW       AM
# 9954  051 Samantha Wells Apt. 328\nScottborough, OR ...  11 vG       AM
# 9981  087 Larson Roads Apt. 587\nRicestad, WI 98077-...  95 Kw       AM
# 9987     2754 Klein Mission\nJohnsonview, PA 64925-9624  65 Fg       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[(df["CC Provider"]=="Mastercard") & (df["Purchase Price"]>50)])
# Out:
# 405

# %%
#Find the email of the person with the following Credit Card Number: 4664825258997302
df[df["Credit Card"]==4664825258997302]["Email"]
# Out:
# 9992    bberry@wright.net
# Name: Email, dtype: object

# %%
#How many people purchase during the AM and how many people purchase during PM?
df["AM or PM"].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %%
#How many people have a credit card that expires in 2020?
def fun():
  count=0
  for date in df("CC Exp Date"):
    if date.split("/")[1]=="20":
      count=count+1
    print(count)

# %%
df[df["CC Exp Date"].apply(lambda x:x[3:]=="20")]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 19                  125 Hall Summit\nBoothton, IL 41721  99 CU       PM
# 32                     Unit 3628 Box 6778\nDPO AE 72362  39 Qm       PM
# 36    9374 Skinner Common Apt. 254\nChristopherfort,...  80 Fq       PM
# 38    9671 Riley Drives Apt. 746\nPort Davidtown, TN...  15 vj       AM
# ...                                                 ...    ...      ...
# 9883        751 Petersen Groves\nLake Rebecca, NM 55875  61 tE       PM
# 9901      908 Norman Burgs\nPhillipsberg, VT 92023-9956  90 Ng       PM
# 9911  44320 Gray Centers Suite 325\nJenniferfurt, OK...  19 Bf       PM
# 9957             73556 Chase Pine\nBrucemouth, MP 73473  25 rU       PM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
#
#                                            Browser Info  \
# ...

# %%
len(df[df["CC Exp Date"].apply(lambda x:x[3:]=="20")])
# Out:
# 988

# %% [markdown]
# #Case Study on Employee Salary Data

# %%
import pandas as pd

# %%
df2=pd.read_csv("/content/Salaries.csv")

# %%
df2
# Out:
#           Id       EmployeeName  \
# 0          1     NATHANIEL FORD
# 1          2       GARY JIMENEZ
# 2          3     ALBERT PARDINI
# 3          4  CHRISTOPHER CHONG
# 4          5    PATRICK GARDNER
# ...      ...                ...
# 49725  49726   Crystal DeFrantz
# 49726  49727   Antoinette Wells
# 49727  49728        Robert Rudy
# 49728  49729       Sean Kerrisk
# 49729  49730      Rachelle Axel
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %%
#o perform data analysis, I have mentioned 21 questions that we are going to solve one by one.
#Display Top 10 Rows of The Dataset

df2.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
#Check Last 10 Rows of The Dataset
df2.tail(10)
# Out:
#           Id      EmployeeName                     JobTitle   BasePay  \
# 49720  49721       Cheryl Wong           IS Administrator 2  84175.04
# 49721  49722      Lorna Gotera       Patient Care Assistant  63995.00
# 49722  49723          Simon Ma             Transit Operator  62867.26
# 49723  49724    Annette Taylor  Senior Management Assistant  84053.71
# 49724  49725      Evelyn Doria    Licensed Vocational Nurse  68865.60
# 49725  49726  Crystal DeFrantz        Emp & Training Spec 4  84086.48
# 49726  49727  Antoinette Wells             Transit Operator  66714.31
# 49727  49728       Robert Rudy          Stationary Engineer  73814.00
# 49728  49729      Sean Kerrisk                    Carpenter  78931.55
# 49729  49730     Rachelle Axel  Senior Management Assistant      8.00
#
#        OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits    Year  \
# 49720         0.00      0.00  36207.16  84175.04         120382.20  2012.0
# ...

# %%
#Find Shape of Our Dataset (Number of Rows And Number of Columns)
df2.shape
# Out:
# (49730, 13)

# %%
print("No. of rows",df2.shape[0])
# Out:
# No. of rows 49730

# %%
print("No. of columns",df2.shape[1])
# Out:
# No. of columns 13

# %%
#Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49730 entries, 0 to 49729
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                49730 non-null  int64
#  1   EmployeeName      49730 non-null  object
#  2   JobTitle          49730 non-null  object
#  3   BasePay           49730 non-null  float64
#  4   OvertimePay       49729 non-null  float64
#  5   OtherPay          49729 non-null  float64
#  6   Benefits          13570 non-null  float64
#  7   TotalPay          49729 non-null  float64
#  8   TotalPayBenefits  49729 non-null  float64
#  9   Year              49729 non-null  float64
#  10  Notes             0 non-null      float64
#  11  Agency            49729 non-null  object
#  12  Status            0 non-null      float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 4.9+ MB

# %%
#Check Null Values In The Dataset
df2.isnull().sum()
# Out:
# Id                      0
# EmployeeName            0
# JobTitle                0
# BasePay                 0
# OvertimePay             1
# OtherPay                1
# Benefits            36160
# TotalPay                1
# TotalPayBenefits        1
# Year                    1
# Notes               49730
# Agency                  1
# Status              49730
# dtype: int64

# %%
#Get Overall Statistics About The Dataframe
df2.describe()
# Out:
#                 Id        BasePay    OvertimePay       OtherPay      Benefits  \
# count  49730.00000   49730.000000   49729.000000   49729.000000  13570.000000
# mean   24865.50000   75598.465810    6231.691032    4608.484444  40370.376006
# std    14355.95878   42293.132137   12801.333149    9146.248973   7395.457091
# min        1.00000       0.000000       0.000000       0.000000    189.790000
# 25%    12433.25000   48472.430000       0.000000      20.330000  36080.740000
# 50%    24865.50000   77251.210000     102.380000    1380.000000  38795.040000
# 75%    37297.75000  105934.660000    6673.030000    5922.060000  43152.130000
# max    49730.00000  302578.000000  245131.880000  400184.250000  84681.820000
#
#             TotalPay  TotalPayBenefits          Year  Notes  Status
# count   49729.000000      49729.000000  49729.000000    0.0     0.0
# mean    86440.161334      97456.389337   2011.272879    NaN     NaN
# ...

# %%
df2.describe(include="all")
# Out:
#                  Id EmployeeName          JobTitle        BasePay  \
# count   49730.00000        49730             49730   49730.000000
# unique          NaN        47201              1685            NaN
# top             NaN    KEVIN LEE  TRANSIT OPERATOR            NaN
# freq            NaN            9              2388            NaN
# mean    24865.50000          NaN               NaN   75598.465810
# std     14355.95878          NaN               NaN   42293.132137
# min         1.00000          NaN               NaN       0.000000
# 25%     12433.25000          NaN               NaN   48472.430000
# 50%     24865.50000          NaN               NaN   77251.210000
# 75%     37297.75000          NaN               NaN  105934.660000
# max     49730.00000          NaN               NaN  302578.000000
#
#           OvertimePay       OtherPay      Benefits       TotalPay  \
# count    49729.000000   49729.000000  13570.000000   49729.000000
# ...

# %%
#Drop ID, Notes, Agency, and Status Columns
df2.drop(["Id","Notes","Agency","Status"],axis=1)
# Out:
#             EmployeeName                                        JobTitle  \
# 0         NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1           GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2         ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3      CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4        PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                  ...                                             ...
# 49725   Crystal DeFrantz                           Emp & Training Spec 4
# 49726   Antoinette Wells                                Transit Operator
# 49727        Robert Rudy                             Stationary Engineer
# 49728       Sean Kerrisk                                       Carpenter
# 49729      Rachelle Axel                     Senior Management Assistant
#
#          BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
#Find Occurrence of The Employee Names  (Top 5)
df2["EmployeeName"].value_counts().head(5)
# Out:
# KEVIN LEE      9
# DAVID WONG     8
# MICHAEL LEE    8
# RICHARD LEE    8
# STANLEY LEE    7
# Name: EmployeeName, dtype: int64

# %%
#Find The Number of Unique Job Titles
df2["JobTitle"].nunique()
# Out:
# 1685

# %%
#Total Number of Job Titles Contain Captain
(df2["JobTitle"].str.contains("CAPTAIN",case=False)).count()
# Out:
# 49730

# %%
len(df2["JobTitle"].str.contains("CAPTAIN"))
# Out:
# 49730

# %%
# Display All the Employee Names From Fire Department
df2.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df2[df2["JobTitle"].str.contains("Fire department",case=False)]
# Out:
#           Id        EmployeeName  \
# 4          5     PATRICK GARDNER
# 6          7           ALSON LEE
# 8          9      MICHAEL MORRIS
# 9         10  JOANNE HAYES-WHITE
# 10        11       ARTHUR KENNEY
# ...      ...                 ...
# 5498    5499       VINCENT PEREZ
# 8436    8437       JENSEN RHODES
# 16285  16286     AARON STEVENSON
# 32623  32624        JAMES BARDEN
# 36162  36163  Joanne Hayes-White
#
#                                                JobTitle    BasePay  \
# 4          DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# 6                    BATTALION CHIEF, (FIRE DEPARTMENT)   92492.01
# 8                    BATTALION CHIEF, (FIRE DEPARTMENT)  176932.64
# 9                CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  285262.00
# 10     ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)  194999.39
# ...                                                 ...        ...
# 5498                        LIEUTENANT, FIRE DEPARTMENT   59663.78
# ...

# %%
len(df2[df2["JobTitle"].str.contains("Fire department",case=False)])
# Out:
# 223

# %%
df2[df2["JobTitle"].str.contains("Fire department",case=False)]["EmployeeName"]
# Out:
# 4           PATRICK GARDNER
# 6                 ALSON LEE
# 8            MICHAEL MORRIS
# 9        JOANNE HAYES-WHITE
# 10            ARTHUR KENNEY
#                 ...
# 5498          VINCENT PEREZ
# 8436          JENSEN RHODES
# 16285       AARON STEVENSON
# 32623          JAMES BARDEN
# 36162    Joanne Hayes-White
# Name: EmployeeName, Length: 223, dtype: object

# %%
#Find Minimum, Maximum, and Average BasePay
df2.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df2["TotalPayBenefits"].describe()
# Out:
# count     49729.000000
# mean      97456.389337
# std       61527.144045
# min           0.000000
# 25%       52917.430000
# 50%       91561.890000
# 75%      140845.590000
# max      567595.430000
# Name: TotalPayBenefits, dtype: float64

# %%
df2["TotalPayBenefits"].max()
# Out:
# 567595.43

# %%
df2["TotalPayBenefits"].min()
# Out:
# 0.0

# %%
df2["TotalPayBenefits"].mean()
# Out:
# 97456.38933740876

# %%
#Replace 'Not Provided' in EmployeeName' Column to NaN
import numpy as np

# %%
df2.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
import numpy as np
df2["EmployeeName"].replace("Not provided",np.nan)
# Out:
# 0           NATHANIEL FORD
# 1             GARY JIMENEZ
# 2           ALBERT PARDINI
# 3        CHRISTOPHER CHONG
# 4          PATRICK GARDNER
#                ...
# 49725     Crystal DeFrantz
# 49726     Antoinette Wells
# 49727          Robert Rudy
# 49728         Sean Kerrisk
# 49729        Rachelle Axel
# Name: EmployeeName, Length: 49730, dtype: object

# %%
#We can use this also for replacement without import numpy
df2["EmployeeName"].replace(to_replace="Not provided",value="Nan")
# Out:
# 0           NATHANIEL FORD
# 1             GARY JIMENEZ
# 2           ALBERT PARDINI
# 3        CHRISTOPHER CHONG
# 4          PATRICK GARDNER
#                ...
# 49725     Crystal DeFrantz
# 49726     Antoinette Wells
# 49727          Robert Rudy
# 49728         Sean Kerrisk
# 49729        Rachelle Axel
# Name: EmployeeName, Length: 49730, dtype: object

# %%
#Find Job Title of ALBERT PARDINI
df2.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df2[df2["EmployeeName"]=="ALBERT PARDINI"]
# Out:
#    Id    EmployeeName                         JobTitle    BasePay  \
# 2   3  ALBERT PARDINI  CAPTAIN III (POLICE DEPARTMENT)  212739.13
#
#    OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits    Year  \
# 2    106088.18   16452.6       NaN  335279.91         335279.91  2011.0
#
#    Notes         Agency  Status
# 2    NaN  San Francisco     NaN

# %%
df2[df2["EmployeeName"]=="ALBERT PARDINI"]["JobTitle"]
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
#How Much ALBERT PARDINI Make (Include Benefits)?
df2[df2["EmployeeName"]=="ALBERT PARDINI"]["TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
#Display Name of The Person Having The Highest BasePa
df2["BasePay"].max()
# Out:
# 302578.0

# %%
df2[df2["BasePay"].max()==df2["BasePay"]]
# Out:
#           Id  EmployeeName         JobTitle   BasePay  OvertimePay  OtherPay  \
# 36160  36161  Gregory Suhr  Chief of Police  302578.0          0.0  18974.11
#
#        Benefits   TotalPay  TotalPayBenefits    Year  Notes         Agency  \
# 36160  69810.19  321552.11          391362.3  2012.0    NaN  San Francisco
#
#        Status
# 36160     NaN

# %%
df2[df2["BasePay"].max()==df2["BasePay"]]["EmployeeName"]
# Out:
# 36160    Gregory Suhr
# Name: EmployeeName, dtype: object

# %%
#Find Average BasePay of All Employee Per Year
df2.groupby("Year").mean()["BasePay"]
# Out:
# <ipython-input-64-6bb0055f8afc>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.groupby("Year").mean()["BasePay"]
# Year
# 2011.0     63595.956517
# 2012.0    107586.256820
# Name: BasePay, dtype: float64

# %%
#Find Average BasePay of All Employee Per JobTitle
df2.groupby("JobTitle").mean()["BasePay"]
# Out:
# <ipython-input-66-85b729a9f5bc>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2.groupby("JobTitle").mean()["BasePay"]
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACUPUNCTURIST                                     66374.400000
# ADMINISTRATIVE ANALYST                            63435.628602
#                                                       ...
# Wire Rope Cable Maint Sprv                        88634.010000
# Worker's Comp Supervisor 1                        98807.242500
# X-RAY LABORATORY AIDE                             47664.773077
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# ...

# %%
# Find Average BasePay of Employee Having Job Title ACCOUNTANT
df2[df2["JobTitle"]=="ACCOUNTANT"]["BasePay"]
# Out:
# 19263    65392.01
# 19324    65225.31
# 20992    60076.24
# 25927    42522.30
# 35285        0.00
# Name: BasePay, dtype: float64

# %%
#Find Top 5 Most Common Jobs
df2["JobTitle"].value_counts().head(5)
# Out:
# TRANSIT OPERATOR    2388
# SPECIAL NURSE       1402
# REGISTERED NURSE    1219
# Registered Nurse     996
# CUSTODIAN            796
# Name: JobTitle, dtype: int64
